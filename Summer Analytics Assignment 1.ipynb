# %% [markdown]
# # Start by importing all important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the csv file and assign it to a variable

# %%
movies = pd.read_csv("https://drive.google.com/file/d/1U73P58VAc4EXM98Or9feKnVx9I9FOP_L/view?usp=sharing")
movies
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="Ml6HoVm0yg2887_s8-eXrw">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>imdb
# ...

# %% [markdown]
# # Display shape of dataframe

# %%
movies.shape
# Out:
# (1000, 16)

# %% [markdown]
# # Print all columns of dataframe

# %%
print(movies.columns.tolist())
# Out:
# ['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director', 'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross']

# %% [markdown]
# # Remove the column 'Poster_Link' and update the dataframe

# %%
x=movies.drop('Poster_Link', axis=1)
x
# Out:
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# 3      The Godfather: Part II          1974           A  202 min
# 4                12 Angry Men          1957           U   96 min
# ..                        ...           ...         ...      ...
# 995    Breakfast at Tiffany's          1961           A  115 min
# 996                     Giant          1956           G  201 min
# 997     From Here to Eternity          1953      Passed  118 min
# 998                  Lifeboat          1944         NaN   97 min
# 999              The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 0                       Drama          9.3
# 1                Crime, Drama          9.2
# 2        Action, Crime, Drama          9.0
# ...

# %% [markdown]
# # Set the 'Series_Title' column as the index of dataframe

# %%
df=x.set_index('Series_Title')
df
# Out:
#                          Released_Year Certificate  Runtime  \
# Series_Title
# The Shawshank Redemption          1994           A  142 min
# The Godfather                     1972           A  175 min
# The Dark Knight                   2008          UA  152 min
# The Godfather: Part II            1974           A  202 min
# 12 Angry Men                      1957           U   96 min
# ...                                ...         ...      ...
# Breakfast at Tiffany's            1961           A  115 min
# Giant                             1956           G  201 min
# From Here to Eternity             1953      Passed  118 min
# Lifeboat                          1944         NaN   97 min
# The 39 Steps                      1935         NaN   86 min
#
#                                              Genre  IMDB_Rating  \
# Series_Title
# The Shawshank Redemption                     Drama          9.3
# The Godfather                         Crime, Drama          9.2
# ...

# %% [markdown]
# # Print a list of all the unique Genre

# %%
df['Genre'].unique()
# Out:
# array(['Drama', 'Crime, Drama', 'Action, Crime, Drama',
#        'Action, Adventure, Drama', 'Biography, Drama, History',
#        'Action, Adventure, Sci-Fi', 'Drama, Romance', 'Western',
#        'Action, Sci-Fi', 'Biography, Crime, Drama',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Thriller',
#        'Adventure, Drama, Sci-Fi', 'Animation, Adventure, Family',
#        'Drama, War', 'Crime, Drama, Fantasy', 'Comedy, Drama, Romance',
#        'Crime, Drama, Mystery', 'Crime, Drama, Thriller',
#        'Action, Drama, Mystery', 'Drama, Family, Fantasy', 'Drama, Music',
#        'Biography, Comedy, Drama', 'Drama, Mystery, Sci-Fi',
#        'Biography, Drama, Music', 'Crime, Mystery, Thriller',
#        'Animation, Adventure, Drama', 'Animation, Drama, War',
#        'Adventure, Comedy, Sci-Fi', 'Horror, Mystery, Thriller',
#        'Drama, Romance, War', 'Comedy, Drama, Family',
#        'Animation, Drama, Fantasy', 'Action, Biography, Drama',
# ...

# %% [markdown]
# # 1. What is the Number of Directors in the given dataset ?

# %%
n=len(df['Director'].unique())
n
# Out:
# 548

# %% [markdown]
# # 2. What is the mean, median and standard deviation of IMDB rating in the dataset ?

# %%
print("Mean :" ,df['IMDB_Rating'].mean())
print("Median :" ,df['IMDB_Rating'].median())
print("Standard Deviation :" ,df['IMDB_Rating'].std())
# Out:
# Mean : 7.949300000000012
# Median : 7.9
# Standard Deviation : 0.27549120749200917

# %% [markdown]
# # 3. Which director has directed the most number of movies?

# %%
df['Director'].value_counts().idxmax()
# Out:
# 'Alfred Hitchcock'

# %% [markdown]
# # 4. Name the Movie which has the highest Runtime ?

# %%
df['Runtime'] = df['Runtime'].str.replace(r'\D', '', regex=True).astype(int)
df
df[['Runtime']].idxmax()
# Out:
# Runtime    Gangs of Wasseypur
# dtype: object

# %% [markdown]
# # 5.How many movies are released after year 2000 and have IMDB rating > 8.5 ?

# %%
df = df.drop('Apollo 13')
df['Released_Year'] = pd.to_numeric(df['Released_Year'])
df['IMDB_Rating'] = pd.to_numeric(df['IMDB_Rating'])
movie_list = df[(df['Released_Year'] > 2000) & (df['IMDB_Rating'] > 8.5) ]
movie_list[movie_list.columns[0]].count()
# Out:
# 11

# %% [markdown]
# # Using seaborn make different types of plots, observe the trend and answer the questions.

# %% [markdown]
# # 6. Make a countplot of Movies directed by all directors.

# %%
sns.countplot(y='Director',data=df)
sns.set(rc={'figure.figsize':(40,100)})
plt.show()

# %% [markdown]
# #  7. Make a plot to analyze distribution of IMDB rating?

# %%
df['IMDB_Rating'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# # 8. What type of Genre has the highest IMDB rating?

# %%
print("Scatter Plot:  ")
plt.scatter(df["IMDB_Rating"], df["Genre"])
plt.show()
# Out:
# Scatter Plot:

# %% [markdown]
# # 9. Name the top 5 movies that have earned highest Meta score.

# %%
df['Series_Title'] = df.index
df.sort_values(by=['Meta_score'], ascending=False).head(5)
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(1,1,1)
ax.bar(df["Series_Title"][:5],df["Meta_score"][:5])
plt.show()

# %% [markdown]
# # 10. Of which Genre movie has the highest Runtime?

# %%
df_hr=df.sort_values(by=['Runtime'], ascending=False).head(500)
# print("Scatter Plot:  ")
# plt.scatter(df["Runtime"], df["Genre"])
# plt.show()
fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(1,1,1)
ax.bar(df_hr["Genre"][:60],df_hr["Runtime"][:60])
plt.xticks(rotation=90)
plt.show()
